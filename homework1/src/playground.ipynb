# %% [markdown]
# # HW1 Playground
#
# Fill in TODOs as you work through the assignment.
# Implement the required sections in `model.py`, and use this notebook to orchestrate and run your solution.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from hw1_loader import HW1DataLoader
from model import GenomicAgeRegressor, HeartDiseaseClassifier

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
# Load both datasets
loader = HW1DataLoader()

heart_path = Path('data/heart.csv')
X_heart, y_heart = loader.get_heart_disease_data(csv_path=heart_path)
print(X_heart.shape, y_heart.value_counts().to_dict())

genomic_path = Path('data/genomic_methylation.csv')
X_genomic, y_genomic, meta_genomic = loader.get_aging_data(csv_path=genomic_path)
print(X_genomic.shape, y_genomic.shape)

# %%
# TODO: EDA for heart dataset (distributions, missing values, class balance)

# %%
# TODO: Train/test split + logistic regression (heart dataset)
from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = ...
# heart_model = HeartDiseaseClassifier(...)
# fit ...

# %%
# TODO: Evaluate (accuracy/precision/recall/F1/ROC-AUC)
# metrics = heart_model.evaluate(...)
# print metrics

# %%
# TODO: Cross-validation (heart)
# cv_results = heart_model.cross_validate(...)
# print metrics

# %%
# TODO: Compare with/without scaling, plot confusion matrix + ROC curve
pass

# %%
# TODO: Train linear regression models on each tissue subset
# Hint: Use dataset column 'tissue_type'
pass

# %%
# TODO: Evaluate MAE/RMSE/R2 on each tissue
pass

# %%
# TODO: Cross-tissue generalization (heatmap/table)
pass

# %%
# TODO: Limited feature selection (top variance 100) and evaluation
pass

# %%
# TODO: Predicted vs actual plots (per tissue)
pass

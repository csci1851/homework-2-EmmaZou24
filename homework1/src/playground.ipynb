# %% [markdown]
# # HW1 Playground
#
# Use this notebook to orchestrate your experiments.
# Complete TODOs in `model.py` first, then fill in the sections below.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

from hw1_loader import HW1DataLoader
from model import GenomicAgeRegressor, HeartDiseaseClassifier
from visualize import plot_decision_boundary

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %% [markdown]
# ## Data Loading

# %%
loader = HW1DataLoader()

heart_path = Path('data/heart.csv')
X_heart, y_heart = loader.get_heart_disease_data(csv_path=heart_path)
print("heart:", X_heart.shape, y_heart.value_counts().to_dict())

genomic_path = Path('data/genomic_methylation.csv')
X_genomic, y_genomic, meta_genomic = loader.get_aging_data(csv_path=genomic_path)
print("genomic:", X_genomic.shape, y_genomic.shape)
print("metadata columns:", list(meta_genomic.columns))

# %% [markdown]
# ## Heart Disease: EDA + Missing Values

# %%
# TODO: inspect distributions of numeric features (hist/box)
# TODO: report class balance (y_heart.value_counts())
# TODO: check missing values (X_heart.isna().sum()) and decide imputation

# %% [markdown]
# ## Heart Disease: Train/Test Split + Logistic Regression

# %%
# TODO: split the heart dataset into train/val (train_test_split)
# TODO: impute missing values on train, then apply to val (avoid leakage)
# TODO: train logistic regression with scaling (see HeartDiseaseClassifier.fit)
# TODO: train another run without scaling (modify preprocess_features or model behavior)
# TODO: compare metrics across both runs

# %% [markdown]
# ## Heart Disease: Evaluation + Curves

# %%
# TODO: compute metrics with heart_model.evaluate (accuracy/precision/recall/F1/ROC-AUC)
# TODO: compute confusion matrix and plot it (sns.heatmap)
# TODO: compute ROC curve with roc_curve and plot it

# %% [markdown]
# ## Heart Disease: Cross-Validation + Decision Boundary

# %%
# TODO: run heart_model.cross_validate on the full dataset
# TODO: summarize CV metrics (mean/std) in a small table 

# TODO: visualize decision boundary using plot_decision_boundary
# plot_decision_boundary(heart_model.model, X_heart, y_heart)

# %% [markdown]
# ## Heart Disease: Feature Importance

# %%
# TODO: rank features using logistic regression coefficients
# TODO: report top positive and negative features with names

# %% [markdown]
# ## Genomic Aging: Tissue-Specific Regression

# %%
# TODO: identify tissue column in meta_genomic (inspect unique values)
# TODO: for each tissue, split into train/val and fit GenomicAgeRegressor
# TODO: store MAE, RMSE, R2 per tissue in a results table

# %% [markdown]
# ## Genomic Aging: Cross-Tissue Generalization

# %%
# TODO: train on one tissue, test on others
# TODO: store results in a tissue x tissue matrix and plot heatmap

# %% [markdown]
# ## Genomic Aging: Feature Selection (Top Variance)

# %%
# TODO: compute per-feature variance on training data
# TODO: select top-K features and retrain the regressor
# TODO: compare metrics to full-feature model

# %% [markdown]
# ## Genomic Aging: Predicted vs Actual Plots

# %%
# TODO: scatter plot of y_true vs y_pred for each tissue
# TODO: include y=x reference line
